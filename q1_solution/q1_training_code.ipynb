# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mDDFkfBq1gfwTMrDsDIr")
project = rf.workspace("ayanneymagix-ymuo5").project("license-plate-mlwlx")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
#   Using cached roboflow-1.2.9-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached roboflow-1.2.9-py3-none-any.whl (88 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.9 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 5.2 MB/s  0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8 model (nano version is fastest to start)
model = YOLO("yolov8n.pt")

# Train it on your dataset
model.train(
    data="license-dataset/data.yaml",
    epochs=300,
    imgsz=640,
    batch=16,
    augment=True
)
# Out:
# Ultralytics 8.3.203  Python-3.11.13 torch-2.8.0+cpu CPU (13th Gen Intel Core i5-13450HX)
# ...

# %%
# Load the trained model
model = YOLO("runs/detect/train2/weights/best.pt")

# Run inference
results = model("license-plate-5/test/images/20250915_141813_953_J001A1_FL_FR_BPC3011_NaN_jpg.rf.bceea9cb70678463ba7c921efbbe18a9.jpg")
results[0].show()
# Out:
# image 1/1 c:\Users\syed sameer\OneDrive\Desktop\license-plate123\license-plate-5\test\images\20250915_141813_953_J001A1_FL_FR_BPC3011_NaN_jpg.rf.bceea9cb70678463ba7c921efbbe18a9.jpg: 512x640 1 broken, 1 non broken, 202.5ms
# Speed: 7.2ms preprocess, 202.5ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
